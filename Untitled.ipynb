# %% [markdown]
# # My firts project

# %% [markdown]
# ## This is a introduction to my project, is my first time doing a jupyter nooteback outside my college

# %% [markdown]
# ## Liguagens de ciências de dados:
# ### Python, R e SQl

# %% [markdown]
# ## Bibliotecas exitem várias, vou citar apenas 6:
# ### TensorFlow,PyTorch,NumPy,Pandas,PySpark,Matplotlib

# %% [markdown]
# ## Tabela de Ferramentas de Ciência de Dados
#
# | Categoria              | Ferramenta          | Descrição rápida |
# |------------------------|----------------------|------------------|
# | Linguagem de Programação | **Python**           | A linguagem mais usada em ciência de dados, com bibliotecas como NumPy, Pandas e Scikit-Learn. |
# | Linguagem de Programação | **R**               | Focada em estatística e visualização, muito usada em pesquisa acadêmica. |
# | Manipulação de Dados     | **Pandas**          | Biblioteca Python para análise e transformação de dados. |
# | Manipulação de Dados     | **dplyr** (R)       | Conjunto de ferramentas para manipulação de dados em R. |
# | Machine Learning         | **Scikit-Learn**    | Biblioteca de ML tradicional (regressão, árvores, clustering). |
# | Machine Learning         | **TensorFlow**      | Framework para deep learning, criado pelo Google. |
# | Machine Learning         | **PyTorch**         | Framework de deep learning muito usado em pesquisa. |
# | Visualização             | **Matplotlib**      | Biblioteca base para gráficos em Python. |
# | Visualização             | **Seaborn**         | Visualizações estatísticas com estilo mais limpo. |
# | Visualização             | **Plotly**          | Gráficos interativos para dashboards. |
# | Big Data                 | **Apache Spark**    | Processamento de grandes volumes de dados distribuídos. |
# | Big Data                 | **Hadoop**          | Ecossistema de armazenamento e processamento distribuído. |
# | ETL / Data Pipeline      | **Airflow**         | Orquestração de fluxos de dados. |
# | ETL / Data Pipeline      | **dbt**             | Transformações de dados em data warehouses. |
# | Data Storage             | **PostgreSQL**      | Banco de dados relacional robusto. |
# | Data Storage             | **MongoDB**         | Banco NoSQL orientado a documentos. |

# %% [markdown]
# ## Exemplos de expressões ariteméticas
# ### 3*3= 9
# ### 4+4= 8

# %%
p= 3*3 
print(p)
s=2+2
print(s)
a=(float(input("digite um valor para ser multiplicado por 2")))
oi=a*2
print(oi)

# %%
mi=float(input("Digite quantos minutos você quer transformar em horas"))
h=mi/60
print(mi,"minutos são:",h,"horas")
# Out:
# Digite quantos minutos você quer transformar em horas 90
# 90.0 minutos são: 1.5 horas

# %% [markdown]
# # *Meus objetivos são me tornar um físico, seja para ser professor ou físico
# # *Quero me mudar para SP
# # *Fazer físcia na USP
# # *Fazer mestrado na Alemanha

# %% [markdown]
# # Meu nome é Humberto de Oliveira Alves
